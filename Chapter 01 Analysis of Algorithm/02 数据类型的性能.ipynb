# %% [markdown]
# 在设计语言中，总的设计方案是让最常用的操作性能最好，牺牲不太常用的操作
# 80/20准则：80%的功能其使用率只有20%
#
# ### List的性能
# 底层是动态数组的实现方式，因此删除是$O(n)$的，读取和赋值这一类是$O(1)$的
#
# ### dict的性能
# 字典是特殊的数据结构Hash table，因此判断 `key in my_dict`是$O(1)$的。会浪费一定的内存空间

# %%
# !pip install big-O

# %%
# 介绍一个可以用来计算时间复杂度的一个包
from big_o import big_o, datagen
best, others = big_o(
    sorted,
    lambda n: datagen.integers(n, 10000, 50000),
    min_n = 1000,
    max_n = 100000,
    n_measures=100,
)
print(best)
